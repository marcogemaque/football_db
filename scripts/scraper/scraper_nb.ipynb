# %%
import re
import requests
#import our scripts
from scraper import get_team_stats
#import third-party
from bs4 import BeautifulSoup
import pandas as pd

#define the HEADER so we can escape TRANSFERMARKT's control
headers = requests.utils.default_headers()
headers.update({
    'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:52.0) Gecko/20100101 Firefox/52.0',
})

# %%
URL = "https://www.transfermarkt.co.uk/ca-river-plate/leistungsdaten/verein/209/reldata/%262022/plus/1"
team_stats = get_team_stats(headers=headers, URL=URL)

# %%
team_stats
# Out:
#   player_number     player_position  ... minutes_played     player_name_fix
# 0             1          Goalkeeper  ...         3.870'       Franco Armani
# 0            33          Goalkeeper  ...           270'  Ezequiel Centurión
# 0            37          Goalkeeper  ...              -     Lucas Lavagnino
# 0             -          Goalkeeper  ...              -      Franco Petroli
# 0            13           Left-Back  ...         2.850'           Enzo Díaz
# 0             2         Centre-Back  ...              -   Sebastián Boselli
# 0            17         Centre-Back  ...         2.390'          Paulo Díaz
# 0            23         Centre-Back  ...           961'     Emanuel Mammana
# 0             -         Centre-Back  ...         1.194'        Robert Rojas
# 0             6         Centre-Back  ...           108'      David Martínez
# 0            15          Right-Back  ...         1.617'      Andrés Herrera
# ...
